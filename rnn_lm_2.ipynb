# %%
import pandas as pd
import re
import math
import torch
from torch import nn
from torch.utils.data import Dataset, DataLoader
import numpy as np

from torch.nn.utils.rnn import pad_sequence
import torch.nn.functional as F

import sentencepiece as spm

from tqdm import tqdm
import random

file = "amazon_review.csv"

data = pd.read_csv(file).dropna(ignore_index=True)
data['overall'] = data["overall"] - 1

vocab_size = 16000
seq_len = 512
pad_token = 16008

spm.SentencePieceTrainer.train(
    input='amazon_reviews.txt',
    model_prefix='amazon_reviews',
    vocab_size=vocab_size,
    model_type='unigram',
    character_coverage=1.0
)

tok = spm.SentencePieceProcessor(model_file='amazon_reviews.model')

filter_ = 1

ls  = [len(tok.encode(i, out_type=int)) for i in data["reviewText"]]

data["lengths"] = ls

data_trunc = data[data["lengths"]<=40]

v = data_trunc["overall"].value_counts()

balanced_data = (
    data_trunc.groupby("overall")
      .sample(n=min(v), random_state=42)
      .reset_index(drop=True)
)

len(balanced_data)

df_shuffled = balanced_data.sample(frac=filter_, random_state=42).reset_index(drop=True)

# Split the shuffled DataFrame
train_size = 0.8
train_df = df_shuffled.sample(frac=train_size, random_state=42).reset_index(drop=True)
test_df = df_shuffled.drop(train_df.index).reset_index(drop=True)
# Out:
# sentencepiece_trainer.cc(78) LOG(INFO) Starts training with :
# trainer_spec {
#   input: amazon_reviews.txt
#   input_format:
#   model_prefix: amazon_reviews
#   model_type: UNIGRAM
#   vocab_size: 16000
#   self_test_sample_size: 0
#   character_coverage: 1
#   input_sentence_size: 0
#   shuffle_input_sentence: 1
#   seed_sentencepiece_size: 1000000
#   shrinking_factor: 0.75
#   max_sentence_length: 4192
#   num_threads: 16
#   num_sub_iterations: 2
#   max_sentencepiece_length: 16
#   split_by_unicode_script: 1
#   split_by_number: 1
#   split_by_whitespace: 1
#   split_digits: 0
#   pretokenization_delimiter:
#   treat_whitespace_as_suffix: 0
#   allow_whitespace_only_pieces: 0
#   required_chars:
#   byte_fallback: 0
#   vocabulary_output_piece_score: 1
#   train_extremely_large_corpus: 0
#   seed_sentencepieces_file:
#   hard_vocab_limit: 1
#   use_all_vocab: 0
#   unk_id: 0
#   bos_id: 1
#   eos_id: 2
#   pad_id: -1
#   unk_piece: <unk>
#   bos_piece: <s>
#   eos_piece: </s>
#   pad_piece: <pad>
#   unk_surface:  ⁇
#   enable_differential_privacy: 0
#   differential_privacy_noise_level: 0
#   differential_privacy_clipping_threshold: 0
# }
# normalizer_spec {
#   name: nmt_nfkc
#   add_dummy_prefix: 1
#   remove_extra_whitespaces: 1
#   escape_whitespaces: 1
#   normalization_rule_tsv:
# }
# denormalizer_spec {}
# trainer_interface.cc(355) LOG(INFO) SentenceIterator is not specified. Using MultiFileSentenceIterator.
# trainer_interface.cc(186) LOG(INFO) Loading corpus: amazon_reviews.txt
# trainer_interface.cc(411) LOG(INFO) Loaded all 112032 sentences
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <unk>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: <s>
# trainer_interface.cc(427) LOG(INFO) Adding meta_piece: </s>
# trainer_interface.cc(432) LOG(INFO) Normalizing sentences...
# trainer_interface.cc(541) LOG(INFO) all chars count=15424622
# trainer_interface.cc(562) LOG(INFO) Alphabet size=95
# trainer_interface.cc(563) LOG(INFO) Final character coverage=1
# trainer_interface.cc(594) LOG(INFO) Done! preprocessed 112032 sentences.
# unigram_model_trainer.cc(265) LOG(INFO) Making suffix array...
# unigram_model_trainer.cc(269) LOG(INFO) Extracting frequent sub strings... node_num=8665450
# unigram_model_trainer.cc(312) LOG(INFO) Initialized 83355 seed sentencepieces
# trainer_interface.cc(600) LOG(INFO) Tokenizing input sentences with whitespace: 112032
# trainer_interface.cc(611) LOG(INFO) Done! 90740
# unigram_model_trainer.cc(602) LOG(INFO) Using 90740 sentences for EM training
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=35198 obj=10.0011 num_tokens=205491 num_tokens/piece=5.83814
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=30303 obj=7.84363 num_tokens=207362 num_tokens/piece=6.84295
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=22723 obj=7.80598 num_tokens=215430 num_tokens/piece=9.4807
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=22710 obj=7.79839 num_tokens=215870 num_tokens/piece=9.5055
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=0 size=17599 obj=7.83138 num_tokens=227650 num_tokens/piece=12.9354
# unigram_model_trainer.cc(618) LOG(INFO) EM sub_iter=1 size=17598 obj=7.82446 num_tokens=227655 num_tokens/piece=12.9364
# trainer_interface.cc(689) LOG(INFO) Saving model: amazon_reviews.model
# trainer_interface.cc(701) LOG(INFO) Saving vocabs: amazon_reviews.vocab

# %%
print("len train df: ", len(train_df))
print("len test df: ", len(test_df))
# Out:
# len train df:  11368
# len test df:  2842

# %%
torch.cuda.empty_cache()

# %%
# get one input output pair with special tokens for later concatenation with other pairs for one sequence under max sequence length
def getEncodingOpen(df, i):
    reviewtext = "Review: "+ df["reviewText"].iloc[i]
    rating = "Rating: " 
    #row = [16000] + tok.encode(reviewText, out_type=int) + [16001] + tok.encode([int(df["overall"].iloc[i])], out_type = int)
    row = [16000] + tok.encode(reviewtext, out_type = int) + [16002] + tok.encode(rating, out_type = int)
    correct_output_rating = int(df["overall"].iloc[i])
    row = torch.LongTensor(row)
    correct_output_rating = torch.LongTensor([correct_output_rating])
    return row, correct_output_rating
# get one input output pair with special tokens for later concatenation with other pairs for one sequence under max sequence length
def getEncoding(df, i):
    reviewtext = "Review: "+ df["reviewText"].iloc[i]
    rating = "Rating: " #+ str(int(df["overall"].iloc[i]))
    score = int(df["overall"].iloc[i])
    row = [16000] + tok.encode(reviewtext, out_type = int) + [16002] + tok.encode(rating, out_type = int) +[score+16003]+ [16001]
    return row

# %%
d = {16000: "<BOS>", 16001: "<EOS>",16002: "<SEP>",16003: "<0>",16004: "<1>",16005: "<2>",16006: "<3>",16007: "<4>", 16008: "PAD"}

def decode_seq(seq):
    outp = ""
    sofar = []
    for i in seq:
        if(i<=15999):
            sofar.append(i)
        else:
            outp += tok.decode(sofar)
            outp += d[i]
            sofar = []
    outp += tok.decode(sofar)
    return outp

# %%
decode_seq(getEncoding(train_df, 2))
# Out:
# '<BOS>Review: deception is written that a lot of cotton and it is very little one synthetics. Instead of the declared 65 percent of 35 percent. unpleasant for such deception<SEP>Rating:<0><EOS>'

# %%
train_df["overall"].iloc[2]
# Out:
# np.float64(0.0)

# %%
print(seq_len)
# Out:
# 512

# %%
def getShiftSeq(df_t, max_seq=1024):
    seqs_x = []
    seqs_y = []
    seqs = []
    c = []
    for i in range(len(df_t)):
        row = getEncoding(df_t, i)
        if len(c) + len(row) > max_seq +1:
            seqs_x.append(c[:-1])
            seqs_y.append(c[1:])
            seqs.append(c)
            c = []
        c.extend(row)
    return seqs_x, seqs_y, seqs

train_seqs_x, train_seqs_y, train_seqs = getShiftSeq(train_df, max_seq=seq_len)
test_seqs_x, test_seqs_y, test_seqs = getShiftSeq(test_df, max_seq=seq_len)

# %%
len(train_seqs_x[0])
# Out:
# 509

# %%
len(train_seqs[0])
# Out:
# 510

# %%
decode_seq(train_seqs[0][-15:])
# Out:
# 'love the shoes but I ordered the wrong size!<SEP>Rating:<3><EOS>'

# %%
train_seqs_x[0][-15:]
# Out:
# [4, 68, 5, 44, 23, 4, 88, 5, 346, 30, 34, 16002, 13254, 292, 16006]

# %%
train_seqs[0][-15:]
# Out:
# [68, 5, 44, 23, 4, 88, 5, 346, 30, 34, 16002, 13254, 292, 16006, 16001]

# %%
class TokenDatasetB(Dataset):
    def __init__(self, seqs_x, seqs_y):
        self.seqs_x = seqs_x
        self.seqs_y = seqs_y
    
    def __len__(self):
        return len(self.seqs_x)
    
    def __getitem__(self, idx):
        return torch.LongTensor(self.seqs_x[idx]), torch.LongTensor(self.seqs_y[idx])

# Padding collate function for variable length sequences
def collate_fnB(batch):
    seqs_x, seqs_y = zip(*batch)
    lens = [len(s) for s in seqs_x]
    max_len = max(lens)
    
    # Pad sequences
    padded_x = torch.zeros(len(seqs_x), max_len, dtype=torch.long) + pad_token
    padded_y = torch.zeros(len(seqs_y), max_len, dtype=torch.long) + pad_token
    
    for i, (x, y) in enumerate(zip(seqs_x, seqs_y)):
        padded_x[i, :len(x)] = x
        padded_y[i, :len(y)] = y
    
    return padded_x, padded_y, torch.LongTensor(lens)

dataset = TokenDatasetB(train_seqs_x, train_seqs_y)
train_loader = DataLoader(dataset, batch_size=50, shuffle=True, collate_fn=collate_fnB)

# %%
for batch_idx, (x, y, lengths) in enumerate(train_loader):
    print("bi")
    print(batch_idx)
    print("x")
    print(x.shape)
    xl = x[0].tolist()
    print(xl)
    print()
    
    
    print(decode_seq(x[0].tolist()))
    print()
    print(decode_seq(x[1].tolist()))
    print()
    print(decode_seq(x[2].tolist()))
    print()
    print(decode_seq(x[3].tolist()))
    print()
    print(decode_seq(x[4].tolist()))
    print()
    print("y")
    print(y)
    print(y.shape)
    print("lengths")
    print(lengths.shape)
    break
# Out:
# bi
# 0
# x
# torch.Size([5, 506])
# [16000, 7421, 292, 1618, 5, 442, 23, 14, 33, 53, 371, 16, 5, 462, 7, 8, 199, 30, 33, 36, 696, 3, 662, 9, 91, 200, 208, 3, 16002, 13254, 292, 16005, 16001, 16000, 7421, 292, 129, 69, 36, 91, 192, 98, 208, 67, 196, 17, 896, 158, 3, 129, 27, 179, 24, 479, 11, 101, 7, 69, 36, 670, 3, 16002, 13254, 292, 16007, 16001, 16000, 7421, 292, 70, 10, 15, 8, 82, 148, 23, 4, 88, 8, 156, 838, 25, 14, 69, 1022, 18, 615, 3, 70, 275, 36, 3, 4, 107, 6701, 10, 7, 4726, 3369, 3, 16002, 13254, 292, 16005, 16001, 16000, 7421, 292, 255, 985, 11, 5, 89, 6, 5232, 15, 19, 74, 184, 3, 16002, 13254, 292, 16006, 16001, 16000, 7421, 292, 181, 148, 11, 556, 526, 16002, 13254, 292, 16005, 16001, 16000, 7421, 292, 1110, 78, 146, 43, 8, 11065, 15580, 79, 3, 16002, 13254, 292, 16004, 16001, 16000, 7421, 292, 4, 88, 8, 2803, 4, 41, 8, 1310, 16, 454, 10, 15, 7, 22, 63, 53, 117, 34, 4, 242, 10, 108, 88, 8, 4229, 16002, 13254, 292, 16005, 16001, 16000, 7421, 292, 606, 244, 9, 209, 28, 79, 3, 5892, 29, 1847, 204, 453, 191, 2438, 3, 815, 584, 208, 3, 16002, 13254, 292, 16004, 16001, 16000, 7421, 292, 246, 33, 55, 82, 23, 53, 78, 11, 5, 125, 16002, 13254, 292, 16003, 16001, 16000, 7421, 292, 39, 1187, 13, 988, 7, 18, 559, 102, 514, 5, 104, 3, 16002, 13254, 292, 16007, 16001, 16000, 7421, 292, 5, 153, 113, 36, 26, 51, 71, 60, 3, 69, 43, 9, 248, 21, 23, 129, 3178, 18, 11273, 28, 5, 222, 2060, 383, 16002, 13254, 292, 16003, 16001, 16000, 7421, 292, 3888, 6, 31, 496, 102, 78, 3, 39, 2019, 33, 66, 43, 110, 1615, 26, 688, 3, 39, 2637, 617, 10, 29, 8863, 1478, 3, 2217, 3, 16002, 13254, 292, 16003, 16001, 16000, 7421, 292, 1267, 73, 4, 27, 858, 5, 495, 28, 75, 3, 224, 329, 49, 7, 2011, 9, 495, 28, 3, 16002, 13254, 292, 16006, 16001, 16000, 7421, 292, 2751, 11, 1835, 16, 8620, 16002, 13254, 292, 16007, 16001, 16000, 7421, 292, 1186, 15, 78, 3, 1266, 23, 205, 30, 33, 36, 16, 1515, 11, 5, 30, 264, 3, 16002, 13254, 292, 16005, 16001, 16000, 7421, 292, 147, 18, 871, 16002, 13254, 292, 16007, 16001, 16000, 7421, 292, 860, 10, 29, 961, 136, 368, 34, 606, 78, 7, 14, 809, 1765, 35, 681, 35, 4, 209, 14, 28, 34, 224, 429, 34, 39, 93, 33, 172, 925, 56, 4, 105, 34, 4, 33, 631, 40, 5614, 34, 16002, 13254, 292, 16003, 16001, 16000, 7421, 292, 266, 103, 191, 11, 110, 1441, 404, 7, 241, 1385, 3, 16002, 13254, 292, 16004, 16001, 16000, 7421, 292, 96, 19, 328, 56, 5, 466, 587, 689, 25, 5, 1227, 521, 3, 16002, 13254, 292, 16004, 16008, 16008, 16008, 16008, 16008, 16008, 16008, 16008, 16008, 16008, 16008, 16008, 16008, 16008, 16008, 16008, 16008, 16008, 16008, 16008, 16008, 16008, 16008, 16008]
#
# <BOS>Review: Loved the boot but it was too loose in the heel and a smaller size was not available. Had to buy another brand.<SEP>Rating:<2><EOS><BOS>Review: i would not buy any other brand or style of sports bra. i have worn these bras for years and would not change.<SEP>Rating:<4><EOS><BOS>Review: It's a nice shirt but I ordered a large hoping that it would cover my bottom. It does not. I am 5'8' and 125lb.<SEP>Rating:<2><EOS><BOS>Review: Nice hoodie for the price, wristbands are little tight.<SEP>Rating:<3><EOS><BOS>Review: Good shirt for cool weather<SEP>Rating:<2><EOS><BOS>Review: To small fits like a penguin tuxedo .<SEP>Rating:<1><EOS><BOS>Review: I ordered a 4.5 I wear a 6.5 in women's and they were too big! I should've ordered a 3.5<SEP>Rating:<2><EOS><BOS>Review: Too hard to put on .didnt zip down front enough zippers. Ordered dickies brand.<SEP>Rating:<1><EOS><BOS>Review: length was just nice but too small for the waist<SEP>Rating:<0><EOS><BOS>Review: The photo is accurate and my wife really likes the watch.<SEP>Rating:<4><EOS><BOS>Review: the jeans do not fit well at all. would like to return them but i missed my deadline on the Amazon drop box<SEP>Rating:<0><EOS><BOS>Review: Wow, this runs really small. The XXL was more like an athletic fit XL. The print wasn't centered correctly. Disappointed.<SEP>Rating:<0><EOS><BOS>Review: First time I have gotten the slip on shoe. So far comfortable and convenient to slip on.<SEP>Rating:<3><EOS><BOS>Review: Gift for nephew in Africa<SEP>Rating:<4><EOS><BOS>Review: Runs small. Returned but larger size was not in stock for the size needed.<SEP>Rating:<2><EOS><BOS>Review: Love my chucks<SEP>Rating:<4><EOS><BOS>Review: Don't waste your money! Too small and it ran literally as soon as I put it on! So disappointed! The color was also lighter than I expected! I was overall very dissatisfied!<SEP>Rating:<0><EOS><BOS>Review: Not long enough for an adult costume and pretty flimsy.<SEP>Rating:<1><EOS><BOS>Review: These are longer than the 32 inches inseam that the tag says.<SEP>Rating:<1>PADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPAD
#
# <BOS>Review: Great shoe tree. Exactly what you need and they smell great. I will update if something goes wrong with them but they seem very sturdy<SEP>Rating:<4><EOS><BOS>Review: The sizes are not right<SEP>Rating:<0><EOS><BOS>Review: Weird hook--not standard for front-hook bras. Couldn't get it hooked--needed help. Then, it didn't fit--cut the breasts.<SEP>Rating:<1><EOS><BOS>Review: Not enough support for my ankles.<SEP>Rating:<1><EOS><BOS>Review: Reminded me of shoes for people who have a real foot problem and I do not. Thank God for that.....<SEP>Rating:<1><EOS><BOS>Review: Terrible!!!!! The lace is so uncomfortable & made my thighs and surrounding skin break out with burn marks. Stick with Hanes!!!!!!<SEP>Rating:<0><EOS><BOS>Review: Awesome shoes<SEP>Rating:<4><EOS><BOS>Review: Ver stiff<SEP>Rating:<2><EOS><BOS>Review: Perfect fit<SEP>Rating:<4><EOS><BOS>Review: Great pants!<SEP>Rating:<3><EOS><BOS>Review: You get what you pay for. It's fine for a cheap Halloween costume, but is not stellar.<SEP>Rating:<2><EOS><BOS>Review: So do Levis and Dockers<SEP>Rating:<1><EOS><BOS>Review: Ordered a 32 waist that fit like a 30 inch. Where's Dickies quality control?<SEP>Rating:<0><EOS><BOS>Review: Dickies is a brand that is consistant in sizing and quality. Very satisfied with fit and quality, would buy again.<SEP>Rating:<4><EOS><BOS>Review: Thanks for saving me money on my grand-daughters shoes. Really nice looking and the real thing. She loves them!<SEP>Rating:<4><EOS><BOS>Review: Flimsy and kind of small, but okay for the purpose for which it was bought.<SEP>Rating:<2><EOS><BOS>Review: These shoes are the most comfortable shoes, I would buy another pair. They fit really well and there a great look.<SEP>Rating:<4><EOS><BOS>Review: Got my hubby's usual size 34/30 and WAY too small. Thinner denim too.<SEP>Rating:<2><EOS><BOS>Review: excellent shoe, very satisfied.<SEP>Rating:<4><EOS><BOS>Review: They are cute, especially for the province. When you wear 11N is is unrealistic to find shoes that cost less than $30.<SEP>Rating:<3><EOS><BOS>Review: Cheaply made, save your money or spend a little more on better product.<SEP>Rating:<1>PADPADPADPADPADPAD
#
# <BOS>Review: All his work pants are Dickies. I ordered the same size, but the ones I received are way to small. Would like to return them.<SEP>Rating:<1><EOS><BOS>Review: To long need to be 28"<SEP>Rating:<1><EOS><BOS>Review: I did not know that Converse stooped that low to get their products made in Vietnam or else I would never have bought them for my young nephew.<SEP>Rating:<0><EOS><BOS>Review: Runs a little larger than actual size, unless you like your sweatshirts roomy. I don't. No problems returning though. Hassle free.<SEP>Rating:<1><EOS><BOS>Review: materials is heavy, scratchy and uncomfortable. Doesn't soften up with washings.<SEP>Rating:<0><EOS><BOS>Review: sorry horrible see heading...<SEP>Rating:<0><EOS><BOS>Review: These hoodies are paper thin. Great for summertime, but if your looking for a warm hoodie this is far from warm.<SEP>Rating:<1><EOS><BOS>Review: Just as expected from Dockers. Great pants.<SEP>Rating:<4><EOS><BOS>Review: Very nice fit good<SEP>Rating:<4><EOS><BOS>Review: The strap looks good, but after about a month it started "shedding" threads from the sides.<SEP>Rating:<2><EOS><BOS>Review: ok<SEP>Rating:<4><EOS><BOS>Review: good shirt will buy again<SEP>Rating:<3><EOS><BOS>Review: These pants are great, I might buy a couple more. Material is great, fits well. Thank you Dickies for these pants<SEP>Rating:<3><EOS><BOS>Review: Too small<SEP>Rating:<2><EOS><BOS>Review: I wear size 36x32 in every other pants, but not these. I would need to order either a 38x30 or maybe even a 40x30.<SEP>Rating:<0><EOS><BOS>Review: looks, feels great.<SEP>Rating:<4><EOS><BOS>Review: The pink on here looks lighter or more pale than what it is in person. Might bleach it or something? Just not what was expected.<SEP>Rating:<2><EOS><BOS>Review: Too small<SEP>Rating:<1><EOS><BOS>Review: This bra is so comfy and great for the long days.<SEP>Rating:<4><EOS><BOS>Review: Didn't like the look of these at all. Returned them<SEP>Rating:<1><EOS><BOS>Review: The insole has started to separate from the bottom of the shoe. A little annoying after only having these for less than 2 months.<SEP>Rating:<1>PADPADPADPADPADPADPADPADPADPADPAD
#
# <BOS>Review: The sweatshirt is roomy but it is too short.<SEP>Rating:<2><EOS><BOS>Review: Its Carharrtt. Its quality<SEP>Rating:<3><EOS><BOS>Review: These are a very nice pair of stockings. They are thick, have nice shimmer, and will go great with my dress that I am wearing for the wedding. A very good bargain!<SEP>Rating:<4><EOS><BOS>Review: Really comfortable<SEP>Rating:<3><EOS><BOS>Review: Great quality for the price!<SEP>Rating:<4><EOS><BOS>Review: Very nice<SEP>Rating:<4><EOS><BOS>Review: It is beautiful and perfectly fit<SEP>Rating:<4><EOS><BOS>Review: The toe area is very thin and you can see your toes through the material.<SEP>Rating:<1><EOS><BOS>Review: The cut of these pants run smaller than standard sizes, I have to return them for a larger size. Hopefully that goes well.<SEP>Rating:<2><EOS><BOS>Review: Arrived broken in pieces<SEP>Rating:<0><EOS><BOS>Review: Beautiful Boots - Should have not ordered the EEE width but other than that they are a great look.<SEP>Rating:<3><EOS><BOS>Review: I bought these shoes because they were pretty cheap and I like the Saucony brand. These are very comfy, light, and I wear them everywhere. I will probably be buying in other colors!<SEP>Rating:<4><EOS><BOS>Review: I don't know if you sent me a women shoe or what? It was to narrow i have the same shoe and it fit fine.<SEP>Rating:<1><EOS><BOS>Review: Did not like the material. bought them to weld in but they are made of polyester, so can't wear them welding. Overall poor quality. Saw a better pair at the swap meet.<SEP>Rating:<1><EOS><BOS>Review: I've previously bought the shoe labeled as womens, but same size. These feel a bit large<SEP>Rating:<2><EOS><BOS>Review: great<SEP>Rating:<4><EOS><BOS>Review: The quality is great...but it is kinda small! Didnt fit to me!<SEP>Rating:<2><EOS><BOS>Review: I am a plus size and I got 5x because it went with my height and they are still to small. So they are definetly not true plus size stockings<SEP>Rating:<0><EOS><BOS>Review: I love this shoe!<SEP>Rating:<4><EOS><BOS>Review: I wanted to love them except they were already ripped when i opened them, unfortunately i needed them for a date & didn't check before hand.....<SEP>Rating:<1>
#
# <BOS>Review: Love these shoes! Nice looking with slacks for work and wear well for long walks.<SEP>Rating:<4><EOS><BOS>Review: These pants ripped the first day I wore them.<SEP>Rating:<0><EOS><BOS>Review: These jeans seem 1/2 or 1 full size smaller than the same sized pants from the store. I sent them back without issues.<SEP>Rating:<2><EOS><BOS>Review: Way too large, gave my daughter horrible blisters all over her feet. Not the size shipped as stated.<SEP>Rating:<0><EOS><BOS>Review: By this item too sizes smaller.<SEP>Rating:<1><EOS><BOS>Review: very comfortable. Love my bibs.<SEP>Rating:<4><EOS><BOS>Review: They run a little tight.<SEP>Rating:<3><EOS><BOS>Review: A tad tight on the waist. Great pants though.<SEP>Rating:<4><EOS><BOS>Review: Very good buy, durable and comfortable, very satisfied<SEP>Rating:<3><EOS><BOS>Review: Great socks! Expensive (maybe a little TOO so) but 'real deal' comfy and warm.<SEP>Rating:<3><EOS><BOS>Review: Looks nice, Feels good but a little high waisted. Other then that I like them on. Yes, I do recomend them.<SEP>Rating:<3><EOS><BOS>Review: Total disaster. Trouser so tight at the thighs.<SEP>Rating:<0><EOS><BOS>Review: Excellent work pants. Currently own 4 pair. Just know the size rans a little small<SEP>Rating:<3><EOS><BOS>Review: My daughter LOVED them. But I ordered a size down based on other reviews.<SEP>Rating:<3><EOS><BOS>Review: Husband frowned at buying wool socks in the summertime..........wears them everyday.<SEP>Rating:<4><EOS><BOS>Review: nice way to keep your shoes when you're not in them.<SEP>Rating:<3><EOS><BOS>Review: Dickies are very inconsistant for me when buying shorts. usually run smaller than sized but these will fit fine. just cant beat the price here.<SEP>Rating:<2><EOS><BOS>Review: These stockings were very nice, but ran small.<SEP>Rating:<2><EOS><BOS>Review: These are the smallest 42x30s I've ever attempted to put on. They fit more like a 36. Which means they didn't fit at all!!!<SEP>Rating:<1><EOS><BOS>Review: Like these for working around the house when it warm outside<SEP>Rating:<3><EOS><BOS>Review: Girlfriend LOVED them! These make a great gift in the fall!<SEP>Rating:<4>PADPADPADPAD
#
# y
# tensor([[ 7421,   292,  1618,  ..., 16008, 16008, 16008],
#         [ 7421,   292,    83,  ..., 16008, 16008, 16008],
#         [ 7421,   292,   564,  ..., 16008, 16008, 16008],
#         [ 7421,   292,    39,  ...,   292, 16004, 16001],
#         [ 7421,   292,   147,  ..., 16008, 16008, 16008]])
# torch.Size([5, 506])
# lengths
# torch.Size([5])

# %%
if torch.cuda.is_available():
    print("CUDA is available!")
    print(f"CUDA device count: {torch.cuda.device_count()}")
    print(f"Current CUDA device name: {torch.cuda.get_device_name(0)}")
    device = 'cuda'
else:
    print("CUDA is not available. PyTorch will use the CPU.")
    device = 'cpu'
# Out:
# CUDA is available!
# CUDA device count: 1
# Current CUDA device name: NVIDIA GeForce RTX 4080 SUPER

# %%
def save_checkpoint(model, optimizer, step, path):
    ckpt = {
        "model": model.state_dict(),
        "optimizer": optimizer.state_dict(),
        "step": step,
    }
    torch.save(ckpt, path)

# %%
# LSTM Model
class LSTMNextToken(nn.Module):
    def __init__(self, vocab_size, embed_dim=512, hidden_dim=1024, num_layers=2, dropout=0.2):
        super().__init__()
        self.embedding = nn.Embedding(vocab_size, embed_dim, padding_idx=0)
        self.lstm = nn.LSTM(embed_dim, hidden_dim, num_layers, 
                           batch_first=True, dropout=dropout if num_layers > 1 else 0)
        self.dropout = nn.Dropout(dropout)
        self.fc = nn.Linear(hidden_dim, vocab_size)
    
    def forward(self, x, lengths):
        embedded = self.embedding(x)
        
        # Pack padded sequence
        packed = nn.utils.rnn.pack_padded_sequence(
            embedded, lengths.cpu(), batch_first=True, enforce_sorted=False
        )
        
        packed_out, _ = self.lstm(packed)
        
        # Unpack
        output, _ = nn.utils.rnn.pad_packed_sequence(packed_out, batch_first=True)
        
        output = self.dropout(output)
        logits = self.fc(output)
        
        return logits

# %%
len(train_loader)
# Out:
# 24

# %%
# Training function
def train_model(model, train_loader, epochs=10, lr=1e-4, device='cuda'):
    model = model.to(device)
    criterion = nn.CrossEntropyLoss(ignore_index=0)  # Ignore padding
    optimizer = torch.optim.Adam(model.parameters(), lr=lr)
    track_loss = []
    global_step = 0
    for epoch in range(epochs):
        model.train()
        total_loss = 0

        loader = tqdm(train_loader)
        
        for x, y, lengths in loader:
            x, y = x.to(device), y.to(device)
            lengths = lengths.to(device)
            
            optimizer.zero_grad()
            
            # Forward pass
            logits = model(x, lengths)
            
            # Reshape for loss calculation
            logits = logits.view(-1, logits.size(-1))
            y = y.view(-1)
            
            loss = criterion(logits, y)
            
            # Backward pass
            loss.backward()
            torch.nn.utils.clip_grad_norm_(model.parameters(), 1.0)
            optimizer.step()
            
            total_loss += loss.item()
            track_loss.append(loss.item())
            avg_loss = sum(track_loss[-10:]) / 10
            loader.set_postfix(loss=avg_loss)
            del logits
            torch.cuda.empty_cache()
            global_step+=1

            ckpt_path = f"ckpt_{epoch}.pt"
            if global_step % 2500 == 0:
                save_checkpoint(model, optimizer, global_step, ckpt_path)
                print(f"Saved checkpoint at step {global_step}")
        
        avg_loss = total_loss / len(train_loader)
        print(f'Epoch {epoch+1}/{epochs}, Average Loss: {avg_loss:.4f}')
    
    return model

# %%
dataset = TokenDatasetB(train_seqs_x, train_seqs_y)
train_loader = DataLoader(dataset, batch_size=12, shuffle=True, collate_fn=collate_fnB)


# Initialize model (set vocab_size to your tokenizer's vocab size + special tokens)
vocab_size = 16000+9  # Adjust based on your tokenizer
model = LSTMNextToken(vocab_size=vocab_size,  num_layers=12)

# %%
total_params = sum(p.numel() for p in model.parameters())
print(f"Total parameters: {total_params}")
# Out:
# Total parameters: 123270281

# %%
# Train
model = train_model(model, train_loader, epochs=20, lr=1e-4)
# Out:
# 100%|████████████████████████████████| 48/48 [00:17<00:00,  2.75it/s, loss=5.77]
# Epoch 1/20, Average Loss: 7.2164
# 100%|████████████████████████████████| 48/48 [00:17<00:00,  2.77it/s, loss=5.73]
# Epoch 2/20, Average Loss: 5.7165
# 100%|████████████████████████████████| 48/48 [00:17<00:00,  2.77it/s, loss=5.68]
# Epoch 3/20, Average Loss: 5.6892
# 100%|████████████████████████████████| 48/48 [00:17<00:00,  2.76it/s, loss=5.66]
# Epoch 4/20, Average Loss: 5.6803
# 100%|████████████████████████████████| 48/48 [00:17<00:00,  2.77it/s, loss=5.65]
# Epoch 5/20, Average Loss: 5.6701
# 100%|████████████████████████████████| 48/48 [00:17<00:00,  2.76it/s, loss=5.67]
# Epoch 6/20, Average Loss: 5.6704
# 100%|████████████████████████████████| 48/48 [00:17<00:00,  2.77it/s, loss=5.65]
# Epoch 7/20, Average Loss: 5.6654
# 100%|████████████████████████████████| 48/48 [00:17<00:00,  2.78it/s, loss=5.64]
# Epoch 8/20, Average Loss: 5.6621
# 100%|████████████████████████████████| 48/48 [00:17<00:00,  2.77it/s, loss=5.66]
# Epoch 9/20, Average Loss: 5.6613
# 100%|████████████████████████████████| 48/48 [00:17<00:00,  2.76it/s, loss=5.69]
# Epoch 10/20, Average Loss: 5.6606
# 100%|████████████████████████████████| 48/48 [00:17<00:00,  2.76it/s, loss=5.68]
# Epoch 11/20, Average Loss: 5.6548
# 100%|████████████████████████████████| 48/48 [00:17<00:00,  2.76it/s, loss=5.66]
# Epoch 12/20, Average Loss: 5.6557
# 100%|████████████████████████████████| 48/48 [00:17<00:00,  2.76it/s, loss=5.65]
# Epoch 13/20, Average Loss: 5.6518
# 100%|████████████████████████████████| 48/48 [00:17<00:00,  2.76it/s, loss=5.64]
# Epoch 14/20, Average Loss: 5.6506
# 100%|████████████████████████████████| 48/48 [00:17<00:00,  2.76it/s, loss=5.65]
# Epoch 15/20, Average Loss: 5.6475
# 100%|████████████████████████████████| 48/48 [00:17<00:00,  2.75it/s, loss=5.63]
# Epoch 16/20, Average Loss: 5.6458
# 100%|████████████████████████████████| 48/48 [00:17<00:00,  2.78it/s, loss=5.65]
# Epoch 17/20, Average Loss: 5.6467
# 100%|████████████████████████████████| 48/48 [00:17<00:00,  2.74it/s, loss=5.64]
# Epoch 18/20, Average Loss: 5.6462
# 100%|████████████████████████████████| 48/48 [00:17<00:00,  2.76it/s, loss=5.66]
# Epoch 19/20, Average Loss: 5.6438
# 100%|████████████████████████████████| 48/48 [00:17<00:00,  2.77it/s, loss=5.63]
# Epoch 20/20, Average Loss: 5.6404

# %%
model.eval()
# Out:
# LSTMNextToken(
#   (embedding): Embedding(16009, 512, padding_idx=0)
#   (lstm): LSTM(512, 1024, num_layers=12, batch_first=True, dropout=0.2)
#   (dropout): Dropout(p=0.2, inplace=False)
#   (fc): Linear(in_features=1024, out_features=16009, bias=True)
# )

# %%
k = [345, 23, 44, 99]
kt = torch.tensor(k)

# %%
seq_len
# Out:
# 512

# %%
anno, score = getEncodingOpen(test_df, random.randint(0,len(test_df)))

# %%
annot = torch.tensor(anno)
# Out:
# /tmp/ipykernel_62526/4078374235.py:1: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   annot = torch.tensor(anno)

# %%
decode_seq(anno.tolist())
# Out:
# '<BOS>Review: Did not fit<SEP>Rating:'

# %%
annot
# Out:
# tensor([16000,  7421,   292,  1480,    36,    26, 16002, 13254,   292])

# %%
score
# Out:
# tensor([0])

# %%
lens = len(anno)
anno_len = torch.tensor([lens])

# Pad sequences
padded_x = torch.zeros(1, 512, dtype=torch.long) + pad_token
padded_x[0,:lens] = torch.tensor(anno)

padded_x = padded_x.to(device)
anno_len = anno_len.to(device)
# Out:
# /tmp/ipykernel_62526/1037303179.py:6: UserWarning: To copy construct from a tensor, it is recommended to use sourceTensor.detach().clone() or sourceTensor.detach().clone().requires_grad_(True), rather than torch.tensor(sourceTensor).
#   padded_x[0,:lens] = torch.tensor(anno)

# %%
padded_x[0].shape
# Out:
# torch.Size([512])

# %%
anno_len
# Out:
# tensor([9], device='cuda:0')

# %%
decode_seq(padded_x[0].tolist())
# Out:
# '<BOS>Review: Did not fit<SEP>Rating:...'

# %%
out = model(padded_x, anno_len)

# %%
out.shape
# Out:
# torch.Size([1, 9, 16009])

# %%
tokenout = torch.argmax(out,dim=2)[0]

# %%
score
# Out:
# tensor([0])

# %%
tokenout.shape
# Out:
# torch.Size([9])

# %%
decode_seq(tokenout.tolist())
# Out:
# 'Review::::::::'

# %%
def predict_label_ids(model, x, pad_token, anno_len):
    model.eval()
    with torch.no_grad():
        logits = model(x, anno_len)                    # (B, T, V)
        nonpad_len = (x != pad_token).sum(dim=1)   # (B,)
        last_pos = nonpad_len - 1
        last_logits = logits[torch.arange(x.size(0)), last_pos]   # (B, V)
        probs = last_logits.softmax(dim=-1)
        top5 = probs.topk(5, dim=-1)
        top1 = probs.topk(1, dim = -1)
        return top5, probs[:, 16003:16008], top1   # top5 and probs specifically for label tokens

# Example:
#x = torch.LongTensor([padded_x]).to(device)
top5, label_probs, top1 = predict_label_ids(model, padded_x, pad_token, anno_len)
print("label_probs:", label_probs.cpu().numpy())
print("top5 ids:", top5.indices.cpu().numpy())
print("top1 ids:", top1.indices.cpu().numpy())
# Out:
# label_probs: [[0.00684289 0.00620727 0.00698792 0.00641123 0.00813268]]
# top5 ids: [[  292     3  7421 16002 13254]]
# top1 ids: [[292]]

# %%
decode_seq(top1[1].tolist()[0]), score.item()
# Out:
# (':', 0)

# %%
class ICLDataset(Dataset):
    def __init__(self, df, shots, seq_len):
        self.df = df
        self.shots = shots
        self.seq_len = seq_len
    
    def __len__(self):
        return len(self.df)

    def getpre(self, idx, l):
        for _ in range(10):
            ixs = []
            xs = []
            for j in range(self.shots):
                sel = idx
                while(sel==idx):
                    sel = random.randint(0, self.__len__() -1)
                xs.extend(getEncoding(self.df, sel))
            if(len(xs) + l <= seq_len):
                return torch.LongTensor(xs)
        raise ValueError(f"can't fit {self.shots} examples in context")
                
            
    
    def __getitem__(self, idx):
        x, y = getEncodingOpen(self.df, idx)
        l = len(x)
        pre = self.getpre(idx, l)
        icl_x = torch.cat((pre,x))
        return icl_x, y

# Padding collate function for variable length sequences
def collate_fn_icl(batch):
    seqs_x, y = zip(*batch)
    lens = [len(s) for s in seqs_x]
    max_len = max(lens)
    
    # Pad sequences
    padded_x = torch.zeros(len(seqs_x), max_len, dtype=torch.long) + pad_token
    
    for i, x in enumerate(seqs_x):
        padded_x[i, :len(x)] = x
    
    return padded_x, torch.LongTensor(y), torch.LongTensor(lens)

# %%
icl_dataset = ICLDataset(train_df, 0, seq_len)
icl_loader = DataLoader(icl_dataset, batch_size=8, shuffle=True, collate_fn=collate_fn_icl)

# %%
for batch_idx, (x, y, lengths) in enumerate(icl_loader):
    print("bi")
    print(batch_idx)
    print("x")
    print(x.shape)
    xl = x[0].tolist()
    print(xl)
    print()
    
    
    print(decode_seq(xl))
    print("y")
    print(y)
    print(y.shape)
    print("lengths")
    print(lengths.shape)
    break
# Out:
# bi
# 0
# x
# torch.Size([8, 45])
# [16000, 7421, 292, 2491, 894, 1048, 974, 373, 3, 16002, 13254, 292, 16008, 16008, 16008, 16008, 16008, 16008, 16008, 16008, 16008, 16008, 16008, 16008, 16008, 16008, 16008, 16008, 16008, 16008, 16008, 16008, 16008, 16008, 16008, 16008, 16008, 16008, 16008, 16008, 16008, 16008, 16008, 16008, 16008]
#
# <BOS>Review: Band broke within four months.<SEP>Rating:PADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPAD
# y
# tensor([2, 1, 1, 1, 4, 2, 0, 2])
# torch.Size([8])
# lengths
# torch.Size([8])

# %%
def israting(s):
    bnk = ["0","1","2","3","4"]
    return s in bnk
def isnum(s):
    bnk = [str(n) for n in range(0,20)]
    return s in bnk

def check_token_list(token_list):
    isratings = 0
    isnums = 0
    for token in token_list:
        isratings += 1 if israting(token) else 0
        isnums += 1 if isnum(token) else 0
    return isratings, isnums

# %%
d
# Out:
# {16000: '<BOS>',
#  16001: '<EOS>',
#  16002: '<SEP>',
#  16003: '<0>',
#  16004: '<1>',
#  16005: '<2>',
#  16006: '<3>',
#  16007: '<4>',
#  16008: 'PAD'}

# %%
def get_score(x):
    x = x.tolist()
    for i in range(len(x)-1,0, -1):
        if 16003<= x[i] <=16007:
            return x[i]
    return 20000

# %%
test_ex = torch.tensor([ 7421,   292,     4,     6,   945,    35,   161,    19,    31,   161,
             6,    18,   161,    19,    10,    29,    26,   143,   204,     3,
            28,   321,    14,   143,    75,   460, 13254,   292, 16000, 16008,
         16008, 16008, 16008, 16008, 16008, 16008, 16008, 16008, 16008, 16008,
         16008, 16008, 16008, 16008, 16008, 16008, 16008, 16008, 16008, 16008,
         16008, 16008, 16008, 16008, 16008, 16008, 16008, 16008, 16008, 16008,
         16008])
vv = get_score(test_ex)

# %%
vv
# Out:
# 20000

# %%
def getTokenScore(t):
    if(t==20000):
        return '-'
    return d[t][1]

# %%
icl_dataset = ICLDataset(train_df, 0, seq_len)
icl_loader = DataLoader(icl_dataset, batch_size=8, shuffle=True, collate_fn=collate_fn_icl)

# %%
tot = 0
num = 0
ratings = 0
correct = 0
for batch_idx, (x, y, lengths) in enumerate(icl_loader):
    x = x.to(device)
    y = y.to(device)
    lengths = lengths.to(device)
    pred_logits = model(x,lengths)
    print(x.shape)
    print(x[0])
    for sequence in x:
        print(decode_seq(sequence.tolist()))
        print()
    print("========================")
    pred_tokens = torch.argmax(pred_logits,dim=2)
    pred_tokens = pred_tokens.to('cpu')
    #pred_tokens = trim_tail(pred_tokens, pad_token)
    #pred_last_token = pred_tokens[:,-1].tolist()
    pred_last_token = [get_score(i) for i in pred_tokens]
    for sequence in pred_tokens:
        print(decode_seq(sequence.tolist()))
        print()
    pred_scores = []
    print(pred_last_token)
    for token in pred_last_token:
        if(token<=15999):
            pred_scores.append(tok.decode([token]))
        else:
            pred_scores.append(getTokenScore(token))

    print('---')
    print(pred_scores)
    
    ys = [str(ans) for ans in y.tolist()]
    print(ys)
    tot += len(y)
    for t in range(len(y)):
        correct += 1 if pred_scores[t] == ys[t] else 0
    isratings, isnums = check_token_list(pred_scores)
    num += isnums
    ratings += isratings
    torch.cuda.empty_cache()
    break
# Out:
# torch.Size([8, 40])
# tensor([16000,  7421,   292,  1822,     9,    31,   208,     3,   588,   787,
#          4163,    26,    13,    47,    23,   660,    10,    29,   102,  1607,
#            16,    21,   406,     3, 16002, 13254,   292, 16008, 16008, 16008,
#         16008, 16008, 16008, 16008, 16008, 16008, 16008, 16008, 16008, 16008],
#        device='cuda:0')
# <BOS>Review: New to this brand. Initial fit is good but haven't really walked in them yet.<SEP>Rating:PADPADPADPADPADPADPADPADPADPADPADPADPAD
#
# <BOS>Review: Don't waste money. Tore apart after first use. Very poor quality of material. The color is not black if you order barely black. It came as grey<SEP>Rating:
#
# <BOS>Review: Very well made and sized just right. Looks great in use.<SEP>Rating:PADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPAD
#
# <BOS>Review: poor quality<SEP>Rating:PADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPAD
#
# <BOS>Review: A full size too large<SEP>Rating:PADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPAD
#
# <BOS>Review: Shoes fell apart rather quickly (2 months), bought adult pair that fell apart as well!<SEP>Rating:PADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPAD
#
# <BOS>Review: We usually love this brand but the shirt is massive!! Go at least two sizes smaller , maybe its a fraud brand not sure<SEP>Rating:PADPADPADPADPADPAD
#
# <BOS>Review: Donot hate it, but returned it. Ordered 2 since I was undecided.<SEP>Rating:PADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPAD
#
# ========================
# Review::::::::::::::::::::::::::PADPADPADPADPADPADPADPADPADPADPADPADPAD
#
# Review:::::::::::::::::::::::::::::::::::::::
#
# Review::::::::::::::::::PADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPAD
#
# Review:::::::PADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPAD
#
# Review::::::::::PADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPAD
#
# Review::::::::::::::::::::::PADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPAD
#
# Review:::::::::::::::::::::::::::::::::PADPADPADPADPADPAD
#
# Review:::::::::::::::::::::PADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPADPAD
#
# [20000, 20000, 20000, 20000, 20000, 20000, 20000, 20000]
# ---
# ['-', '-', '-', '-', '-', '-', '-', '-']
# ['3', '0', '3', '1', '1', '1', '1', '0']

# %%
print("tot: ", tot)
print("num: ", num)
print("ratings: ", ratings)
print("correct: ", correct)
# Out:
# tot:  8
# num:  0
# ratings:  0
# correct:  0

# %%
icl_dataset = ICLDataset(test_df, 2, seq_len)
icl_loader = DataLoader(icl_dataset, batch_size=8, shuffle=True, collate_fn=collate_fn_icl)

# %%
tot = 0
num = 0
ratings = 0
correct = 0
for batch_idx, (x, y, lengths) in enumerate(icl_loader):
    x = x.to(device)
    y = y.to(device)
    lengths = lengths.to(device)
    pred_logits = model(x,lengths)
    #print(x.shape)
    #print(x[0])
    #for sequence in x:
    #    print(decode_seq(sequence.tolist()))
    #    print()
    #print("========================")
    pred_tokens = torch.argmax(pred_logits,dim=2)
    pred_tokens = pred_tokens.to('cpu')
    #pred_tokens = trim_tail(pred_tokens, pad_token)
    #pred_last_token = pred_tokens[:,-1].tolist()
    pred_last_token = [get_score(i) for i in pred_tokens]
    #for sequence in pred_tokens:
    #    print(decode_seq(sequence.tolist()))
    #    print()
    pred_scores = []
    #print(pred_last_token)
    for token in pred_last_token:
        if(token<=15999):
            pred_scores.append(tok.decode([token]))
        else:
            pred_scores.append(getTokenScore(token))

    #print('---')
    #print(pred_scores)
    
    ys = [str(ans) for ans in y.tolist()]
    #print(ys)
    tot += len(y)
    for t in range(len(y)):
        correct += 1 if pred_scores[t] == ys[t] else 0
    isratings, isnums = check_token_list(pred_scores)
    num += isnums
    ratings += isratings
    torch.cuda.empty_cache()

# %%
print("tot: ", tot)
print("num: ", num)
print("ratings: ", ratings)
print("correct: ", correct)
print("acc: ", correct/tot)
# Out:
# tot:  2842
# num:  0
# ratings:  0
# correct:  0
# acc:  0.0

# %%
 4778 / 15396
